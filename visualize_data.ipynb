# %%
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# '/home/kapur16/cs587/cs587project'

# %%
df_cross_0_300_500_300 = \
pd.read_csv("/home/kapur16/cs587/cs587project/books_results/DCN_V1/curve_plot_0crossLayers__[300, 500, 300]_deepLayers[]concatLayers_20epochs1e-05LR/results.csv")

# %%
logistic_regression = pd.read_csv("/home/kapur16/cs587/cs587project/books_results/DCN_V1/curve_plot_0crossLayers__[]_deepLayers[]concatLayers_20epochs1e-05LR/results.csv")

df_v1cross_1_300_300 = \
pd.read_csv("books_results/DCN_V1/curve_plot_1crossLayers__[300, 300]_deepLayers[]concatLayers_20epochs1e-05LR/results.csv")


df_v2cross_1_300_300 = \
pd.read_csv("books_results/DCN_V2/curve_plot_1crossLayers__[300, 300]_deepLayers[]concatLayers_20epochs1e-05LR/results.csv")

# %%
df_loss = pd.DataFrame({'Epochs': df_cross_0_300_500_300['EPOCHS'], 
                   'Standard DeepNet, 0 Cross Layers, [300, 500, 300]': df_cross_0_300_500_300['Validation Loss'], 
                    'Logistic Regression': logistic_regression['Validation Loss'],
                   'DCN V1, 1 Cross Layers [300, 300]': df_v1cross_1_300_300['Validation Loss'],
                 'DCN V2, 1 Cross Layers [300, 300]': df_v2cross_1_300_300['Validation Loss']})

df_accuracy = pd.DataFrame({'Epochs': df_cross_0_300_500_300['EPOCHS'], 
                   'Standard DeepNet, 0 Cross Layers, [300, 500, 300]': df_cross_0_300_500_300['Validation Accuracy'],
                     'Logistic Regression': logistic_regression['Validation Accuracy'],
                   'DCN V1, 1 Cross Layers [300, 300]': df_v1cross_1_300_300['Validation Accuracy'],
                 'DCN V2, 1 Cross Layers [300, 300]': df_v2cross_1_300_300['Validation Accuracy']})

# %%
df_melted_loss = df_loss.melt(id_vars=['Epochs'], var_name='Architecture', value_name='Loss')
df_melted_accuracy = df_accuracy.melt(id_vars=['Epochs'], var_name='Architecture', value_name='Accuracy')

# %%
#sns.set_style("whitegrid")
sns.set_theme(style='dark')

# %%
pd.option_context('mode.use_inf_as_na', True)

# %%
with pd.option_context('mode.use_inf_as_na', True):
    # Create a line plot using Seaborn
    sns.lineplot(data=df_melted_loss, x='Epochs', y='Loss', hue='Architecture')
    # Show the plot
    plt.title('Loss vs Epochs.')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()
# Out:
# <ipython-input-48-76316e7a220d>:1: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
with pd.option_context('mode.use_inf_as_na', True):
    # Create a line plot using Seaborn
    sns.lineplot(data=df_melted_accuracy, x='Epochs', y='Accuracy', hue='Architecture')
    # Show the plot
    plt.title('Accuracy vs Epochs.')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()
# Out:
# <ipython-input-49-81de828a740f>:1: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df.head()
# Out:
#    Epochs  Standard DeepNet, 0 Cross Layers, [300, 300, 300]  \
# 0       0                                          -0.002367
# 1       1                                          -0.002876
# 2       2                                          -0.003242
# 3       3                                          -0.003449
# 4       4                                          -0.003619
#
#    DCN V1, 1 Cross Layers [300, 300]  DCN V2, 1 Cross Layers [300, 300]
# 0                          -0.002264                          -0.002264
# 1                          -0.002682                          -0.002682
# 2                          -0.003077                          -0.003077
# 3                          -0.003337                          -0.003337
# 4                          -0.003493                          -0.003493

# %%
df_cross0 = pd.read_csv("/home/kapur16/cs587/cs587project/books_results/DCN_V2/curve_plot_0crossLayers__[300, 500, 300]_deepLayers[]concatLayers_20epochs1e-05LR/results.csv")
df_cross1 = pd.read_csv("/home/kapur16/cs587/cs587project/books_results/DCN_V1/curve_plot_1crossLayers__[300, 300]_deepLayers[]concatLayers_20epochs1e-05LR/results.csv")
df_cross2 = pd.read_csv("/home/kapur16/cs587/cs587project/books_results/DCN_V1/curve_plot_2crossLayers__[300, 300]_deepLayers[]concatLayers_20epochs1e-05LR/results.csv")
df_cross3 = pd.read_csv("/home/kapur16/cs587/cs587project/books_results/DCN_V1/curve_plot_3crossLayers__[300, 300]_deepLayers[]concatLayers_20epochs1e-05LR/results.csv")
df_cross4 = pd.read_csv("/home/kapur16/cs587/cs587project/books_results/DCN_V1/curve_plot_1crossLayers__[300, 300]_deepLayers[]concatLayers_20epochs1e-05LR/results.csv")
df_cross5 = pd.read_csv("/home/kapur16/cs587/cs587project/books_results/DCN_V1/curve_plot_5crossLayers__[300, 300]_deepLayers[200, 100]concatLayers_20epochs1e-05LR/results.csv")
df_cross6 = pd.read_csv("/home/kapur16/cs587/cs587project/books_results/DCN_V1/curve_plot_6crossLayers__[300, 300]_deepLayers[200, 100]concatLayers_20epochs1e-05LR/results.csv")

# %%
losses = [df_cross0['Validation Loss'].min(), df_cross1['Validation Loss'].min(),
df_cross2['Validation Loss'].min(),
df_cross3['Validation Loss'].min(),
df_cross4['Validation Loss'].min(), df_cross5['Validation Loss'].min(), df_cross6['Validation Loss'].min()]

# %%
layers = [0,1,2,3,4, 5, 6]
accuracies = [df_cross0['Validation Accuracy'].max(), df_cross1['Validation Accuracy'].max(),
df_cross2['Validation Accuracy'].max(),
df_cross3['Validation Accuracy'].max(),
df_cross4['Validation Accuracy'].max(),df_cross5['Validation Accuracy'].max(),
             df_cross6['Validation Accuracy'].max()]

# %%
sns.lineplot(x=layers, y=accuracies, color='red')
plt.title('Accuracy vs Number of Cross Layers.')
plt.xlabel('Number of Cross Layers')
plt.ylabel('Accuracy')
plt.show()
# Out:
# /home/kapur16/.conda/envs/cent7/2020.11-py38/cs587/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/kapur16/.conda/envs/cent7/2020.11-py38/cs587/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/kapur16/.conda/envs/cent7/2020.11-py38/cs587/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.lineplot(x=layers, y=losses, color='red')
plt.title('Loss vs Number of Cross Layers.')
plt.xlabel('Number of Cross Layers')
plt.ylabel('Loss')
plt.show()
# Out:
# /home/kapur16/.conda/envs/cent7/2020.11-py38/cs587/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/kapur16/.conda/envs/cent7/2020.11-py38/cs587/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/kapur16/.conda/envs/cent7/2020.11-py38/cs587/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
